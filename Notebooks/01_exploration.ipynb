# %% [markdown]
# ## 1. Import Thư Viện và Cấu Hình Môi Trường
#
# Bước này thực hiện việc thiết lập môi trường cần thiết cho quá trình phân tích và xử lý dữ liệu:
#
# *   **System & Path**: Thêm thư mục char (parent directory) vào system path để có thể import các modules tùy chỉnh từ thư mục `Src`.
# *   **Custom Modules**:
#     *   CryptoDataProcessor: Class hỗ trợ tải, kiểm tra và xử lý dữ liệu crypto (xử lý missing, outlier, duplicates).
#     *   CryptoVisualizer: Class chuyên dụng để vẽ các biểu đồ phân tích (phân phối, candlestick, correlation).
# *   **Libraries**: Import các thư viện phân tích dữ liệu tiêu chuẩn (`pandas`, `numpy`) và trực quan hóa (`matplotlib`, `seaborn`).
# *   **Cấu hình hiển thị**:
#     *   **Pandas**: Hiển thị đầy đủ các cột, tối đa 100 dòng, và định dạng số thực với 6 chữ số thập phân (để nhìn rõ giá các coin nhỏ).
#     *   **Matplotlib/Seaborn**: Thiết lập style `seaborn-v0_8-darkgrid` và bảng màu `husl` để biểu đồ đẹp và dễ nhìn hơn. Kích thước mặc định của hình là 12x8 inches.
# *   **Warnings**: Bỏ qua các cảnh báo không cần thiết để output gọn gàng hơn.

# %%
# ==============================================================================
# DATA EXPLORATION AND PREPROCESSING NOTEBOOK
# Đồ án phân tích dữ liệu thị trường crypto - Phần 2.2 & 2.3
# Sử dụng CryptoDataProcessor từ data_processor.py
# Sử dụng CryptoVisualizer từ visualizer.py
# ==============================================================================

# 1. IMPORT THƯ VIỆN VÀ MODULES
# ==============================================================================
import sys
import os
sys.path.append('..')

# Import custom modules
from Src.data_exploration import CryptoDataProcessor
from Src.visualization import CryptoVisualizer

# Import các thư viện khác
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Thiết lập hiển thị
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', '{:.6f}'.format)
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['font.size'] = 12


print("="*80)
print("PHÂN TÍCH DỮ LIỆU VÀ TIỀN XỬ LÝ - CRYPTO HOURLY DATA")
print("Phần 2.2: Data Exploration and Preprocessing")
print("="*80)
# Out:
# ...
# PHÂN TÍCH DỮ LIỆU VÀ TIỀN XỬ LÝ - CRYPTO HOURLY DATA
# Phần 2.2: Data Exploration and Preprocessing
# ...

# %% [markdown]
# ### 2. Tải, Khám Phá và Trực Quan Hóa Dữ Liệu Ban Đầu
#
# Bước này thực hiện việc tải dữ liệu thô, kiểm tra tổng quan và vẽ các biểu đồ phân phối cơ bản:
#
# 1.  **Khởi tạo & Tải dữ liệu CryptoDataProcessor:**
#     *   Đọc file dữ liệu thô từ [Data/raw/crypto_hourly_data.csv]
#     *   [explore_data()]: Hàm này sẽ thực hiện đọc file, hiển thị kích thước dữ liệu, thông tin các cột, và các thống kê mô tả cơ bản (mean, max, min) để có cái nhìn tổng quát về bộ dữ liệu.
#
# 2.  **Trực quan hóa dữ liệu CryptoVisualizer**:
#     *   Khởi tạo đối tượng trực quan hóa với dữ liệu vừa tải.
#     *   **Phân phối giá**: Vẽ biểu đồ so sánh phân phối giữa `Open` vs `Close` và `High` vs `Low`. Điều này giúp kiểm tra xem phân phối giá có bất thường hay lệch nhiều không.
#     *   **Phân phối khối lượng**: Vẽ biểu đồ phân phối cho `Volume` và `Quote Volume` để đánh giá tính thanh khoản và biên độ giao dịch.
#     *   **Biểu đồ nến (Candlestick)**: Vẽ biểu đồ nến cho 3 đồng coin đầu tiên trong danh sách để quan sát trực quan xu hướng giá và biến động theo thời gian.

# %%
# 2. TẢI VÀ KHÁM PHÁ DỮ LIỆU
# ==============================================================================
print("\n" + "="*80)
print("BƯỚC 1: ĐỌC VÀ TẢI DỮ LIỆU")
print("="*80)

# Khởi tạo processor
processor = CryptoDataProcessor(file_path='../Data/raw/crypto_hourly_data.csv')

# Tải và khám phá dữ liệu
df = processor.explore_data()

# Khởi tạo visualizer
visualizer = CryptoVisualizer(df)
visualizer.plot_grouped_distribution('open', 'close')
visualizer.plot_grouped_distribution('high', 'low')
visualizer.plot_single_distribution('volume')
visualizer.plot_single_distribution('quote_volume')
visualizer.plot_candlestick_top3()
# Out:
# ...
# BƯỚC 1: ĐỌC VÀ TẢI DỮ LIỆU
# ...
#  Đã tải 28806 bản ghi, 14 cột
#
# ...
# KIỂM TRA TÍNH HỢP LỆ CỦA DỮ LIỆU
# ...
# PHÂN TÍCH DỮ LIỆU CHI TIẾT
# ...
#
# 0. Ý NGHĨA CÁC CỘT DỮ LIỆU:
# --------------------------------------------------
# • open                     : Giá mở cửa tại đầu mỗi giờ
# • high                     : Giá cao nhất trong giờ
# • low                      : Giá thấp nhất trong giờ
# • close                    : Giá đóng cửa cuối giờ
# • volume                   : Khối lượng giao dịch (base currency)
# • quote_volume             : Khối lượng giao dịch (quote currency)
# • trades_count             : Số lượng giao dịch trong giờ
# • taker_buy_base_volume    : Khối lượng mua từ taker (base)
# • taker_buy_quote_volume   : Khối lượng mua từ taker (quote)
# • timestamp                : Thời điểm bắt đầu của khoảng thời gian
# • date                     : Ngày
# • time                     : Giờ
# • symbol                   : Cặp giao dịch (ví dụ: BTCUSDT)
# ...

# %% [markdown]
# ### 3. Quy Trình Xử Lý Dữ Liệu Tự Động
#
# Bước này thực hiện toàn bộ quy trình làm sạch và chuẩn hóa dữ liệu thông qua pipeline đã được xây dựng trong class CryptoDataProcessor:
#
# 1.  **Xử lý dữ liệu get_processed_data**:
#     *   Hàm này tự động thực hiện chuỗi các thao tác:
#         *   **Xử lý Missing Values**: Điền hoặc loại bỏ các giá trị thiếu hợp lý.
#         *   **Xử lý Duplicates**: Loại bỏ các bản ghi trùng lặp.
#         *   **Xử lý Outliers**: Phát hiện và xử lý các giá trị ngoại lai trong mỗi symbol (có thể dùng phương pháp IQR hoặc Z-score) để tránh ảnh hưởng xấu đến mô hình sau này.
#     *   Kết quả trả về là một DataFrame `df_processed` đã sạch và sẵn sàng cho việc phân tích sâu hơn.
#
# 2.  **Lưu trữ dữ liệu**:
#     *   Dữ liệu sau khi xử lý được lưu vào file Data/processed/fully_processed_data.csv.
#     *   File này sẽ đóng vai trò là dữ liệu đầu vào chuẩn cho các notebook tiếp theo (như Feature Engineering hay Modeling).

# %%
# 3. XỬ LÝ DỮ LIỆU TỰ ĐỘNG
# ==============================================================================
print("\n" + "="*80)
print("BƯỚC 2: XỬ LÝ DỮ LIỆU TỰ ĐỘNG")
print("="*80)

# Lấy dữ liệu đã xử lý hoàn chỉnh
df_processed = processor.get_processed_data()

# Lưu dữ liệu đã xử lý
df_processed.to_csv('../Data/processed/fully_processed_data.csv', index=False)
print(f"\nĐã lưu dữ liệu đã xử lý vào 'Data/processed/fully_processed_data.csv'")
# Out:
# ...
# BƯỚC 2: XỬ LÝ DỮ LIỆU TỰ ĐỘNG
# ...
#
# ...
# BẮT ĐẦU XỬ LÝ DỮ LIỆU HOÀN CHỈNH
# ...
#  Đã tải 28806 bản ghi, 14 cột
#
# ...
# KIỂM TRA TÍNH HỢP LỆ CỦA DỮ LIỆU
# ...
#
# XỬ LÝ MISSING VALUES (Strategy: knn)
#  Không có giá trị missing
#
# XỬ LÝ OUTLIERS (Method: iqr, By Symbol: True)
#   Đã xử lý 5/30 symbols...
#   Đã xử lý 10/30 symbols...
#   Đã xử lý 15/30 symbols...
#   Đã xử lý 20/30 symbols...
#   Đã xử lý 25/30 symbols...
#   Đã xử lý 30/30 symbols...
#
# • Đã xử lý outliers cho 30 symbols
# • Outliers được xử lý (capped):
#   - quote_volume: 2,177 outliers (7.56%)
#   - volume: 2,169 outliers (7.53%)
#   - taker_buy_quote_volume: 2,139 outliers (7.43%)
#   - taker_buy_base_volume: 2,119 outliers (7.36%)
#   - trades_count: 2,077 outliers (7.21%)
#   - high: 471 outliers (1.64%)
#   - close: 466 outliers (1.62%)
#   - low: 452 outliers (1.57%)
#   - open: 446 outliers (1.55%)
#   - Tổng outliers: 12,516
#   - Tỷ lệ outliers: 4.83%
#
# ...
# XỬ LÝ DỮ LIỆU HOÀN TẤT
# ...
#  Kích thước dữ liệu cuối: (28806, 14)
# ...
